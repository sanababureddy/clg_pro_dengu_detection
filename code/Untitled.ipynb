# %%
import numpy as np # linear algebra
import pandas as pd

# %%
data=pd.read_csv("C:/Users/Project_Work_User/Downloads/dengue dataset.csv")

# %%
data
# Out:
#       id  fever vomiting nausea vomiting_blood body_pains pain_behind_eyes  \
# 0      1  102.5       no     no             no        yes               no
# 1      2  101.8       no     no             no        low               no
# 2      3  101.8      yes     no             no        low               no
# 3      4  100.9       no     no             no        yes               no
# 4      5  103.4      yes    yes            yes       high              yes
# 5      6  103.4      yes    yes             no       high              yes
# 6      7  103.3      yes    yes             no       high               no
# 7      8  103.3      yes     no            yes       high              yes
# 8      9  103.2       no     no             no     medium               no
# 9     10  103.2      yes    yes             no        low               no
# 10    11  103.2      yes    yes            yes       high              yes
# 11    12  103.1      yes    yes            yes         no               no
# 12    13  103.1      yes    yes             no         no               no
# 13    14  100.9       no     no             no        yes               no
# 14    15  102.5      yes    yes             no     medium               no
# 15    16  102.3      yes     no             no     medium               no
# 16    17  103.7       no    yes             no     medium               no
# 17    18  101.6       no     no             no        yes               no
# 18    19  103.7       no    yes             no     medium               no
# 19    20  101.6       no     no             no        low               no
# 20    21  101.5       no     no             no        low               no
# 21    22  103.7      yes    yes             no     medium               no
# 22    23  103.1       no     no             no     medium               no
# 23    24  103.5      yes    yes             no        low               no
# 24    25  104.8      yes     no             no       high               no
# 25    26  104.0       no     no             no     medium               no
# 26    27  104.0       no     no             no     medium               no
# 27    28  104.0       no     no             no     medium               no
# 28    29  102.6      yes     no             no     medium               no
# 29    30  102.6      yes     no             no     medium               no
# ..   ...    ...      ...    ...            ...        ...              ...
# 194  195  104.4       no     no             no        yes               no
# 195  196  104.5       no     no            yes       high              yes
# 196  197  103.5      yes    yes             no        low               no
# 197  198  103.1       no     no             no        low               no
# 198  199  102.4       no     no             no        low               no
# 199  200  102.6       no     no             no        low               no
# 200  201  100.2       no    yes             no        low               no
# 201  202  103.7       no     no             no     medium               no
# 202  203  101.9       no     no             no        low               no
# 203  204  101.8       no     no             no        low               no
# 204  205  101.8      yes    yes            yes         no               no
# 205  206  101.1       no     no             no        low               no
# 206  207  102.3       no     no             no     medium               no
# 207  208  102.3       no     no             no     medium               no
# 208  209  101.4       no     no             no     medium               no
# 209  210  102.2      yes    yes            yes         no               no
# 210  211   99.2      yes     no             no        low               no
# 211  212  102.1       no     no             no        low               no
# 212  213  102.1       no     no             no        low               no
# 213  214   99.6       no     no             no        low               no
# 214  215  103.9      yes    yes             no     medium              yes
# 215  216  103.5      yes    yes             no       high              yes
# 216  217  103.6      yes    yes            yes       high              yes
# 217  218  104.4       no     no             no        yes               no
# 218  219  103.3       no     no             no     medium               no
# 219  220  103.3       no     no             no     medium               no
# 220  221  102.6       no     no             no         no               no
# 221  222  103.8       no    yes             no       high               no
# 222  223  102.3      yes     no             no     medium               no
# 223  224  102.6       no     no             no         no               no
#
#     joint_pains chill headache swollen_glands rashes abdominal_pain ble_nose  \
# 0            no   yes      yes             no    yes             no       no
# 1            no    no      yes             no     no             no       no
# 2            no   yes      yes             no     no             no       no
# 3            no   yes      yes             no    yes             no      yes
# 4        medium   yes   medium            yes     no            yes      yes
# 5        medium   yes   medium            yes     no            yes      yes
# 6          high   yes      low             no     no            yes       no
# 7          high   yes   medium            yes     no            yes      yes
# 8            no    no       no             no     no            yes       no
# 9          high   yes      low             no    yes            yes      yes
# 10         high   yes      low            yes     no            yes      yes
# 11           no    no      yes            yes     no             no       no
# 12           no    no      yes            yes     no             no       no
# 13           no   yes      yes             no    yes             no      yes
# 14           no   yes      yes             no     no             no       no
# 15           no   yes       no             no     no            yes       no
# 16           no   yes      yes             no     no             no       no
# 17           no   yes      yes            yes     no             no       no
# 18           no   yes      yes             no     no             no       no
# 19           no   yes      yes             no     no             no       no
# 20           no   yes      yes             no     no             no       no
# 21           no   yes      yes             no    yes             no      yes
# 22           no    no      yes             no     no             no       no
# 23           no    no      yes             no     no             no       no
# 24           no   yes      yes             no    yes             no       no
# 25           no   yes      yes             no    yes             no       no
# 26           no   yes      yes             no    yes             no       no
# 27           no   yes      yes             no    yes             no       no
# 28           no   yes      yes            yes     no             no       no
# 29       medium   yes      yes            yes     no             no       no
# ..          ...   ...      ...            ...    ...            ...      ...
# 194          no   yes      yes             no    yes             no       no
# 195        high   yes   medium            yes     no            yes      yes
# 196          no    no      yes             no     no             no       no
# 197          no   yes      yes             no     no             no       no
# 198          no    no      yes             no     no             no       no
# 199          no   yes      yes             no     no             no       no
# 200          no   yes      yes             no     no             no       no
# 201          no   yes      yes            yes     no             no       no
# 202          no    no      yes             no     no             no       no
# 203          no    no      yes             no     no             no       no
# 204          no    no      yes             no     no             no       no
# 205          no    no      yes             no     no             no       no
# 206          no    no      yes             no    yes             no       no
# 207          no    no      yes             no    yes             no       no
# 208          no   yes      yes             no     no             no       no
# 209          no    no      yes             no    yes             no       no
# 210          no   yes      yes             no     no             no       no
# 211          no   yes      yes             no    yes             no       no
# 212          no   yes      yes             no    yes             no       no
# 213          no   yes      yes             no     no             no       no
# 214      medium   yes   medium            yes    yes            yes      yes
# 215        high   yes     high             no    yes             no      yes
# 216      medium   yes   medium            yes     no            yes       no
# 217          no   yes      yes             no    yes             no       no
# 218          no   yes      yes             no    yes             no       no
# 219          no   yes      yes             no    yes             no       no
# 220          no   yes       no             no     no            yes       no
# 221          no   yes      yes             no     no            yes       no
# 222          no   yes       no             no     no            yes       no
# 223          no   yes       no             no     no            yes       no
#
#     ble_mouth fatigue red_eyes  platelets_count dengue
# 0          no     yes       no           290000     no
# 1          no      no       no           256000     no
# 2          no     yes      yes           165000     no
# 3          no     yes       no           168000     no
# 4          no     yes       no             6800    yes
# 5          no     yes       no             6300    yes
# 6         yes     yes      yes             7900    yes
# 7          no     yes      yes             7500    yes
# 8          no      no       no            45000     no
# 9         yes     yes      yes             7700    yes
# 10         no     yes      yes             6500    yes
# 11         no     yes       no           116000     no
# 12         no     yes       no           116000     no
# 13         no     yes       no           168000     no
# 14         no     yes       no            89000     no
# 15         no      no      yes            98000     no
# 16         no      no       no           153000     no
# 17         no     yes       no           156000     no
# 18         no      no       no           153000     no
# 19         no     yes       no           152000     no
# 20         no      no       no           146000     no
# 21         no     yes       no           140000     no
# 22         no     yes       no           119000     no
# 23         no     yes       no           193000     no
# 24         no      no       no           190000     no
# 25         no     yes       no           185000     no
# 26         no     yes       no           185000     no
# 27         no     yes       no           185000     no
# 28         no     yes       no           176000     no
# 29         no     yes       no           176000     no
# ..        ...     ...      ...              ...    ...
# 194        no     yes       no           199000     no
# 195        no     yes       no             6800    yes
# 196        no     yes       no           193000     no
# 197        no     yes       no            48000     no
# 198        no     yes       no            39000     no
# 199        no     yes       no            38000     no
# 200        no     yes       no            37600     no
# 201        no     yes      yes            37000     no
# 202        no     yes       no           260000     no
# 203        no      no       no           256000     no
# 204        no     yes       no           252000     no
# 205        no      no       no           250000     no
# 206        no     yes       no           249000     no
# 207        no     yes       no           249000     no
# 208        no     yes       no           240000     no
# 209        no     yes       no           224000     no
# 210        no      no       no           220000     no
# 211        no      no       no           220000     no
# 212        no      no       no           220000     no
# 213        no     yes       no           204000     no
# 214        no     yes      yes             6200    yes
# 215       yes     yes      yes             6100    yes
# 216       yes     yes       no             6000    yes
# 217        no     yes       no           199000     no
# 218        no     yes       no           196000     no
# 219        no     yes       no           196000     no
# 220        no      no       no            97000     no
# 221        no     yes      yes            52000     no
# 222        no      no      yes            98000     no
# 223        no      no       no            97000     no
#
# [224 rows x 19 columns]

# %%
data[:,:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-69c5e68d6f90> in <module>
# ----> 1 data[:,:]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2655                                  'backfill or nearest lookups')
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#    2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), slice(None, None, None))' is an invalid key
